# %%
# import image module 
#from IPython.display import Image 
# get the image 
#Image(url="NeuroRide.png", width=1000, height=20)

# %% [markdown]
# ![Neuroride](NeuroRide.png)

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ----------------
# anyio                     4.8.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     24.3.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# boto3                     1.36.12
# botocore                  1.36.12
# certifi                   2024.12.14
# cffi                      1.17.1
# charset-normalizer        3.4.1
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.3.1
# cvzone                    1.6.1
# cycler                    0.12.1
# debugpy                   1.8.11
# decorator                 5.1.1
# defusedxml                0.7.1
# et_xmlfile                2.0.0
# executing                 2.1.0
# fastjsonschema            2.21.1
# filelock                  3.17.0
# filterpy                  1.4.5
# fonttools                 4.55.3
# fqdn                      1.5.1
# fsspec                    2025.2.0
# gdown                     5.2.0
# gitdb                     4.0.12
# GitPython                 3.1.44
# h11                       0.14.0
# httpcore                  1.0.7
# httpx                     0.28.1
# idna                      3.10
# imageio                   2.37.0
# ipykernel                 6.29.5
# ipython                   8.31.0
# ipywidgets                8.1.5
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.5
# jmespath                  1.0.1
# joblib                    1.4.2
# json5                     0.10.0
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2024.10.1
# jupyter                   1.1.1
# jupyter_client            8.6.3
# jupyter-console           6.6.3
# jupyter_core              5.7.2
# jupyter-events            0.11.0
# jupyter-lsp               2.2.5
# jupyter_server            2.15.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.3.4
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# jupyterlab_widgets        3.0.13
# kiwisolver                1.4.8
# lap                       0.5.12
# lazy_loader               0.4
# MarkupSafe                3.0.2
# matplotlib                3.10.0
# matplotlib-inline         0.1.7
# mistune                   3.1.0
# mpmath                    1.3.0
# narwhals                  1.24.2
# nbclient                  0.10.2
# nbconvert                 7.16.5
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# networkx                  3.4.2
# notebook                  7.3.2
# notebook_shim             0.2.4
# numpy                     2.1.1
# opencv-python             4.11.0.86
# openpyxl                  3.1.5
# overrides                 7.7.0
# packaging                 24.2
# pandas                    2.2.3
# pandocfilters             1.5.1
# parso                     0.8.4
# pillow                    11.1.0
# pip                       25.0.1
# platformdirs              4.3.6
# plotly                    6.0.0
# prometheus_client         0.21.1
# prompt_toolkit            3.0.48
# psutil                    6.1.1
# pure_eval                 0.2.3
# py-cpuinfo                9.0.0
# pycparser                 2.22
# pygame                    2.6.1
# Pygments                  2.19.1
# pyparsing                 3.2.1
# PySocks                   1.7.1
# python-dateutil           2.9.0.post0
# python-json-logger        3.2.1
# pytz                      2024.2
# pywin32                   308
# pywinpty                  2.0.14
# PyYAML                    6.0.2
# pyzmq                     26.2.0
# referencing               0.35.1
# requests                  2.32.3
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.22.3
# s3transfer                0.11.2
# scikit-image              0.25.2
# scikit-learn              1.6.1
# scipy                     1.15.1
# seaborn                   0.13.2
# Send2Trash                1.8.3
# setuptools                75.8.0
# six                       1.17.0
# smmap                     5.0.2
# sniffio                   1.3.1
# soupsieve                 2.6
# stack-data                0.6.3
# sympy                     1.13.1
# terminado                 0.18.1
# thop                      0.1.1-2209072238
# threadpoolctl             3.5.0
# tifffile                  2025.2.18
# tinycss2                  1.4.0
# torch                     2.6.0
# torchvision               0.21.0
# tornado                   6.4.2
# tqdm                      4.67.1
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20241206
# typing_extensions         4.12.2
# tzdata                    2024.2
# ultralytics               8.3.78
# ultralytics-thop          2.0.14
# uri-template              1.3.0
# urllib3                   2.3.0
# wcwidth                   0.2.13
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.8.0
# widgetsnbextension        4.0.13

# %% [markdown]
# ### Importing the Dataset for Training the model (Multiple methods)
# - Method 1) Using gdown module and then output the imported dataset **Issue** : Memory Overhead
# - Method 2) Synchronizing GDrive as local disk on our desktop and then specifying the path so that it behaves as a   virtual  disk
# - Method 3) Mount Google Drive via google-drive-ocamlfuse (Linux Only)
# - Method 4)Specify the path directly to dataset on your local machine and train the model

# %% [markdown]
# ### Method 1

# %% [markdown]
# ![](fileid.png)

# %% [markdown]
# ### Importing the DataSet (Training set , Validation set , Test set inclusive )
# import gdown
#
# file_id = "1aBcD123xyz"  #file id from link
#
# output_path = "dataset.zip"  # Choose your filename
#
# gdown.download(f"https://drive.google.com/uc?id={file_id}", output_path, quiet=False)

# %% [markdown]
# ### Method 2

# %% [markdown]
# ![](gdrivedesk.png)

# %% [markdown]
# ### Method 3 (Linux Only)

# %% [markdown]
# 1. Install dependencies:
#
#    !sudo add-apt-repository universe
#
#    !sudo apt install google-drive-ocamlfuse
#
# 2. Authenticate and mount Google Drive:
#
#     !google-drive-ocamlfuse
#
#     !mkdir -p ~/gdrive
#
#     !google-drive-ocamlfuse ~/gdrive
#
# 3. Use your dataset from ~/gdrive/MyDrive/Datasets/NeuroRide/

# %% [markdown]
# ### Method 4 **(This is what we r going to use for now)**

# %%
yolo task=detect mode=train model=yolo11m.pt data=your_data.yaml epochs=100 project="D:\AIML Projects\Trainedweights" imgsz=640
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt to 'yolo11m.pt'...
# Ultralytics 8.3.78 ðŸš€ Python-3.12.6 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i5-12450HX)
# engine\trainer: task=detect, mode=train, model=yolo11m.pt, data=/path/to/your/dataset/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train
#   0%|          | 0.00/38.8M [00:00<?, ?B/s]
#   2%|1         | 768k/38.8M [00:00<00:05, 7.50MB/s]
#   5%|4         | 1.75M/38.8M [00:00<00:04, 8.53MB/s]
#   7%|7         | 2.75M/38.8M [00:00<00:04, 8.76MB/s]
#   9%|9         | 3.62M/38.8M [00:00<00:04, 8.81MB/s]
#  12%|#1        | 4.50M/38.8M [00:00<00:04, 8.90MB/s]
#  14%|#3        | 5.38M/38.8M [00:00<00:03, 8.86MB/s]
#  16%|#6        | 6.25M/38.8M [00:00<00:04, 8.27MB/s]
#  18%|#8        | 7.12M/38.8M [00:00<00:04, 7.71MB/s]
#  21%|##        | 8.00M/38.8M [00:01<00:03, 8.11MB/s]
#  23%|##3       | 9.00M/38.8M [00:01<00:03, 8.61MB/s]
#  25%|##5       | 9.88M/38.8M [00:01<00:03, 8.39MB/s]
#  28%|##7       | 10.8M/38.8M [00:01<00:03, 8.02MB/s]
#  30%|##9       | 11.6M/38.8M [00:01<00:03, 7.59MB/s]
#  32%|###1      | 12.4M/38.8M [00:01<00:05, 4.90MB/s]
#  34%|###3      | 13.0M/38.8M [00:02<00:06, 3.94MB/s]
#  35%|###4      | 13.5M/38.8M [00:02<00:08, 3.30MB/s]
#  36%|###6      | 14.0M/38.8M [00:02<00:08, 3.07MB/s]
#  37%|###7      | 14.4M/38.8M [00:02<00:09, 2.71MB/s]
#  38%|###8      | 14.8M/38.8M [00:02<00:09, 2.63MB/s]
#  39%|###8      | 15.1M/38.8M [00:03<00:10, 2.37MB/s]
#  40%|###9      | 15.4M/38.8M [00:03<00:10, 2.27MB/s]
#  40%|####      | 15.6M/38.8M [00:03<00:10, 2.33MB/s]
#  41%|####      | 15.9M/38.8M [00:03<00:10, 2.37MB/s]
#  42%|####1     | 16.1M/38.8M [00:03<00:10, 2.27MB/s]
#  42%|####2     | 16.4M/38.8M [00:03<00:11, 2.00MB/s]
#  43%|####2     | 16.6M/38.8M [00:03<00:11, 1.95MB/s]
#  43%|####3     | 16.9M/38.8M [00:04<00:11, 1.92MB/s]
#  44%|####4     | 17.1M/38.8M [00:04<00:14, 1.58MB/s]
#  45%|####4     | 17.4M/38.8M [00:04<00:16, 1.37MB/s]
#  45%|####5     | 17.6M/38.8M [00:04<00:17, 1.27MB/s]
#  76%|#######6  | 29.6M/38.8M [00:11<00:06, 1.52MB/s]
#  77%|#######6  | 29.9M/38.8M [00:12<00:05, 1.67MB/s]
#  78%|#######7  | 30.1M/38.8M [00:12<00:04, 1.82MB/s]
#  78%|#######8  | 30.4M/38.8M [00:12<00:04, 1.98MB/s]
#  79%|#######9  | 30.8M/38.8M [00:12<00:03, 2.29MB/s]
#  80%|#######9  | 31.0M/38.8M [00:12<00:03, 2.24MB/s]
#  81%|########  | 31.4M/38.8M [00:12<00:03, 2.38MB/s]
#  82%|########1 | 31.8M/38.8M [00:12<00:03, 2.41MB/s]
#  82%|########2 | 32.0M/38.8M [00:12<00:03, 2.11MB/s]
#  83%|########3 | 32.2M/38.8M [00:13<00:03, 1.95MB/s]
#  84%|########3 | 32.5M/38.8M [00:13<00:03, 1.91MB/s]
#  84%|########4 | 32.8M/38.8M [00:13<00:03, 1.92MB/s]
#  85%|########5 | 33.0M/38.8M [00:13<00:03, 1.98MB/s]
#  86%|########5 | 33.2M/38.8M [00:13<00:02, 2.05MB/s]
#  86%|########6 | 33.5M/38.8M [00:13<00:02, 2.01MB/s]
#  87%|########6 | 33.8M/38.8M [00:14<00:03, 1.34MB/s]
#  88%|########7 | 34.0M/38.8M [00:14<00:04, 1.08MB/s]
#  88%|########8 | 34.2M/38.8M [00:14<00:04, 1.14MB/s]
#  89%|########8 | 34.5M/38.8M [00:14<00:03, 1.22MB/s]
#  90%|########9 | 34.8M/38.8M [00:14<00:03, 1.40MB/s]
#  90%|######### | 35.0M/38.8M [00:15<00:02, 1.50MB/s]
#  91%|######### | 35.2M/38.8M [00:15<00:02, 1.57MB/s]
#  91%|#########1| 35.5M/38.8M [00:15<00:02, 1.71MB/s]
#  92%|#########2| 35.8M/38.8M [00:15<00:01, 1.78MB/s]
#  93%|#########2| 36.0M/38.8M [00:15<00:01, 1.89MB/s]
#  93%|#########3| 36.2M/38.8M [00:15<00:01, 1.93MB/s]
#  94%|#########4| 36.5M/38.8M [00:15<00:01, 1.96MB/s]
#  95%|#########4| 36.8M/38.8M [00:16<00:01, 2.03MB/s]
#  95%|#########5| 37.0M/38.8M [00:16<00:00, 1.95MB/s]
#  96%|#########6| 37.2M/38.8M [00:16<00:00, 1.90MB/s]
#  97%|#########6| 37.5M/38.8M [00:16<00:00, 2.02MB/s]
#  97%|#########7| 37.8M/38.8M [00:16<00:00, 1.83MB/s]
#  98%|#########7| 38.0M/38.8M [00:16<00:00, 1.80MB/s]
#  99%|#########8| 38.2M/38.8M [00:16<00:00, 1.93MB/s]
#  99%|#########9| 38.5M/38.8M [00:17<00:00, 1.85MB/s]
# 100%|#########9| 38.8M/38.8M [00:17<00:00, 1.90MB/s]
# 100%|##########| 38.8M/38.8M [00:17<00:00, 2.37MB/s]
# Traceback (most recent call last):
#   File "C:\Users\shiva\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\trainer.py", line 564, in get_dataset
#     data = check_det_dataset(self.args.data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shiva\AppData\Roaming\Python\Python312\site-packages\ultralytics\data\utils.py", line 316, in check_det_dataset
#     file = check_file(dataset)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shiva\AppData\Roaming\Python\Python312\site-packages\ultralytics\utils\checks.py", line 522, in check_file
#     raise FileNotFoundError(f"'{file}' does not exist")
# FileNotFoundError: '/path/to/your/dataset/data.yaml' does not exist
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\shiva\AppData\Roaming\Python\Python312\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\shiva\AppData\Roaming\Python\Python312\site-packages\ultralytics\cfg\__init__.py", line 986, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shiva\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\model.py", line 804, in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shiva\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\trainer.py", line 134, in __init__
#     self.trainset, self.testset = self.get_dataset()
#                                   ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shiva\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\trainer.py", line 568, in get_dataset
#     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error \u274c {e}")) from e
# RuntimeError: Dataset '/path/to/your/dataset/data.yaml' error  '/path/to/your/dataset/data.yaml' does not exist
